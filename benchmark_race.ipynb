# %% [markdown]
# # 🏎️ Benchmark Launcher
# This notebook launches the `race_runner.py` script manually created to fix Muon distributed errors.

# %%
# !pip uninstall -y muon -q 2>/dev/null 
# !pip install git+https://github.com/KellerJordan/Muon -q
# !pip install wandb datasets transformers accelerate bitsandbytes rich huggingface_hub -q
# !pip install cggr==0.4.3 -q

# %%
# !nvidia-smi

# %%
import os
if not os.path.exists('race_runner.py'):
    print('❌ race_runner.py missing! Check previous steps.')
else:
    print('✅ race_runner.py found.')

# %%
# Run Dry Run (Standard)
# !python race_runner.py --mode standard --dry_run

# %%
# Run Standard Race
# !python race_runner.py --mode standard

# %%
# Run CGGR Race
# !python race_runner.py --mode cggr
